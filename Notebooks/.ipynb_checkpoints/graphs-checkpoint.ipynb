# %%
using CairoMakie
using NetCDF
# Out:
# Precompiling CairoMakie
#   ✓ MakieCore
#   ✓ Makie
#   ✓ CairoMakie
#   3 dependencies successfully precompiled in 129 seconds. 226 already precompiled.
# Precompiling NetCDF
#   ✓ NetCDF_jll
#   ✓ NetCDF
#   2 dependencies successfully precompiled in 3 seconds. 25 already precompiled.

# %%
filename = "/home/gaspard/Documents/Ecole/BX S2/Stage/OceWind/results/data/formated_data.nc"
# Out:
# "/home/gaspard/Documents/Ecole/BX S2/Stage/OceWind/results/data/formated_data.nc"

# %%
function plot_data(data, title)
    fig = Figure(size = (800, 700))
    
    ax_h = Axis(fig[1, 1:2]; title=title, xlabel = "t (minutes)", ylabel = "z (meters)")

    dims = size(data)
    
    hm_w = heatmap!(ax_h, 1:dims[1], LinRange(-128, 0, dims[2]), data)
    Colorbar(fig[1, 3], hm_w)

    ax_l = Axis(fig[2, 1:2]; title = L"%$(title) at t = %$(dims[1]) mins", xlabel = title, ylabel = "z (meters)")
    lines!(ax_l, data[end, :], LinRange(-128, 0, dims[2]))



    return fig


end
# Out:
# plot_data (generic function with 1 method)

# %%
u_bar = ncread(filename, "u_bar")
v_bar = ncread(filename, "v_bar")
w_bar = ncread(filename, "w_bar")
T_bar = ncread(filename, "T_bar")
P_bar = ncread(filename, "P_bar")

T_w_bar = ncread(filename, "T_w_bar")
u_w_bar = ncread(filename, "u_w_bar")
v_w_bar = ncread(filename, "v_w_bar")
u_P_bar = ncread(filename, "u_P_bar")
v_P_bar = ncread(filename, "v_P_bar")
w_P_bar = ncread(filename, "w_P_bar")

energy = ncread(filename, "energy")

1
# Out:
# 1

# %%
u_bar
# Out:
# 601×256 Matrix{Float64}:
#  -2.11564e-10   2.50213e-10  -7.49904e-10  …  -7.14184e-11  -1.52961e-10
#  -2.1156e-10    2.50214e-10  -7.49888e-10      4.50467e-8    0.0358185
#  -2.11548e-10   2.50206e-10  -7.49846e-10      1.79784e-7    0.0716356
#  -2.11529e-10   2.50188e-10  -7.49776e-10      4.06713e-7    0.10745
#  -2.11501e-10   2.5016e-10   -7.49681e-10      7.48471e-7    0.14326
#  -2.11466e-10   2.50122e-10  -7.49559e-10  …   1.23421e-6    0.179066
#  -2.11423e-10   2.50074e-10  -7.49411e-10      1.91619e-6    0.214864
#  -2.11372e-10   2.50015e-10  -7.49236e-10      2.9757e-6     0.250655
#  -2.11313e-10   2.49946e-10  -7.49034e-10      5.2242e-6     0.286435
#  -2.11246e-10   2.49868e-10  -7.48805e-10      1.23035e-5    0.322201
#  -2.11171e-10   2.4978e-10   -7.48548e-10  …   4.2193e-5     0.357935
#  -2.11089e-10   2.49684e-10  -7.48263e-10      0.00019553    0.393545
#  -2.11e-10      2.49579e-10  -7.47951e-10      0.00111229    0.428455
#   ⋮                                        ⋱                 ⋮
#  -0.000229614  -0.000221584  -0.000198459      0.0909812     0.14053
#  -0.000230346  -0.000222245  -0.000199271  …   0.0906405     0.140286
#  -0.000231051  -0.000222822  -0.000199953      0.0908819     0.140563
#  -0.000231728  -0.000223318  -0.000200493      0.0910971     0.140911
#  -0.000232379  -0.000223746  -0.000200905      0.0915293     0.140979
#  -0.000233007  -0.00022413   -0.000201226      0.0912526     0.140758
#  -0.000233618  -0.000224495  -0.000201503  …   0.0911943     0.14039
#  -0.000234217  -0.000224868  -0.000201779      0.0908505     0.140376
#  -0.00023481   -0.000225269  -0.000202089      0.0908977     0.140174
#  -0.000235398  -0.000225707  -0.000202447      0.0912106     0.139852
#  -0.000235981  -0.000226182  -0.000202852      0.0902835     0.139367
#  -0.000236558  -0.000226686  -0.000203294  …   0.0895344     0.138904

# %%
plot_data(u_bar, L"\bar{u}")

# %%
plot_data(v_bar, L"\bar{v}")

# %%
plot_data(w_bar, L"\bar{w}")

# %%
plot_data(T_bar, L"\bar{T}")

# %%
plot_data(P_bar, L"\bar{P}")

# %%
plot_data(T_w_bar, L"T'w'")

# %%
plot_data(u_w_bar, L"u'w'")

# %%
plot_data(v_w_bar, L"v'w'")

# %%
plot_data(u_P_bar, L"u'P'")

# %%
plot_data(v_P_bar, L"v'P'")

# %%
plot_data(w_P_bar, L"w'P'")

# %%
plot_data(energy, L"energy")
